# %%
import os
import sys
import json
import pathlib
from glob import glob
import numpy as np
import pandas as pd
from collections import defaultdict
import time

# Image processing and SSIM evaluation
from PIL import Image
import cv2
from skimage import io
from skimage.util import img_as_ubyte
from skimage.color import gray2rgb, rgb2gray, rgba2rgb
from skimage.transform import resize
from skimage.metrics import structural_similarity as ssim

# Visualization
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import seaborn as sns
from tqdm.notebook import tqdm
from tqdm import tqdm as tqdm_base

# Add source to path for importing PDFExtractor
sys.path.insert(0, '/media/jcardenuto/Windows/Users/phill/work/2025-elis-system/system_modules/pdf-image-extraction')
from src.pdf_image_extraction.core.extractor import PDFExtractor

print("✓ All libraries imported successfully")
# Out:
# ✓ All libraries imported successfully

# %%
# Configuration
BASE_PATH = '../pdf-content-extraction-data/'
REFERENCE_PATH = os.path.join(BASE_PATH, 'pdf-content-extraction-data/figures/')
EXTRACTED_PATH = 'xfigs/'  # Output directory for new version
ANNOTATION_FILE = os.path.join(BASE_PATH, 'pdf-content-extraction-annotation.json')

# SSIM evaluation parameters
MATCH_THRESH = 0.55
USE_ORIGINAL_SIZE = False
RESIZE = (512, 512)

# Create output directories
os.makedirs(EXTRACTED_PATH, exist_ok=True)
os.makedirs(os.path.join(EXTRACTED_PATH, 'results'), exist_ok=True)

# Load annotations
with open(ANNOTATION_FILE) as file:
    annotations = json.load(file)

print(f"✓ Loaded {len(annotations)} PDF annotations")
print(f"✓ Reference images path: {REFERENCE_PATH}")
print(f"✓ New extraction output path: {EXTRACTED_PATH}")

# Get list of PDFs
base_path_full = os.path.join(BASE_PATH, 'pdf-content-extraction-data')
pdfs_dir = os.path.join(base_path_full, 'pdfs')
pdf_files = sorted(glob(os.path.join(pdfs_dir, '*.pdf')))
print(f"✓ Found {len(pdf_files)} PDF files to process")
# Out:
# ✓ Loaded 285 PDF annotations
# ✓ Reference images path: ../pdf-content-extraction-data/pdf-content-extraction-data/figures/
# ✓ New extraction output path: xfigs/
# ✓ Found 285 PDF files to process

# %%
# Load reference images from xfigs
reference_images = {}
reference_pdfs = sorted(glob(os.path.join(REFERENCE_PATH, 'PDF-*')))

for pdf_path in reference_pdfs:
    pdf_id = os.path.basename(pdf_path)
    reference_images[pdf_id] = sorted(glob(os.path.join(pdf_path, '*.*')))

print(f"✓ Loaded reference images from {len(reference_pdfs)} PDFs")
total_ref_images = sum(len(imgs) for imgs in reference_images.values())
print(f"✓ Total reference images: {total_ref_images}")
# Out:
# ✓ Loaded reference images from 285 PDFs
# ✓ Total reference images: 1876

# %%
def extract_pdf_images(pdf_path, output_dir, mode='normal'):
    """
    Extract images from a PDF using the new PDFExtractor
    
    Args:
        pdf_path: Path to PDF file
        output_dir: Directory to save extracted images
        mode: Extraction mode ('safe', 'normal', 'unsafe')
    
    Returns:
        Dictionary with extraction metadata
    """
    pdf_id = os.path.splitext(os.path.basename(pdf_path))[0]
    pdf_output_dir = os.path.join(output_dir, pdf_id)
    os.makedirs(pdf_output_dir, exist_ok=True)
    
    metadata = {
        'pdf_id': pdf_id,
        'pdf_path': pdf_path,
        'mode': mode,
        'images_extracted': 0,
        'extraction_time': 0,
        'error': None
    }
    
    try:
        start_time = time.time()
        extractor = PDFExtractor(pdf_path)
        
        # Use the correct method based on mode
        if mode == 'safe':
            extractor.safe_mode(pdf=pdf_path, dir_path=pdf_output_dir)
        elif mode == 'unsafe':
            extractor.unsafe_mode(pdf=pdf_path, dir_path=pdf_output_dir)
        else:  # normal
            extractor.normal_mode(pdf=pdf_path, dir_path=pdf_output_dir)
        
        metadata['extraction_time'] = time.time() - start_time
        
        # Count extracted images
        extracted_files = glob(os.path.join(pdf_output_dir, '*.png'))
        metadata['images_extracted'] = len(extracted_files)
        
    except Exception as e:
        metadata['error'] = str(e)
        print(f"  ⚠ Error extracting {pdf_id}: {str(e)[:100]}")
    
    return metadata

# Extract images from all PDFs using the new version
extraction_results = []

print("Extracting images using new PyMuPDF 1.26.6 version (normal mode)...")
print("=" * 70)

for pdf_path in tqdm(pdf_files, desc="Processing PDFs"):  # Process first 10 as sample
    result = extract_pdf_images(pdf_path, EXTRACTED_PATH, mode='normal')
    extraction_results.append(result)
    
    if result['error']:
        print(f"  ✗ {result['pdf_id']}: {result['error']}")
    else:
        print(f"  ✓ {result['pdf_id']}: {result['images_extracted']} images, {result['extraction_time']:.2f}s")

# Summary
successful = sum(1 for r in extraction_results if not r['error'])
total_extracted = sum(r['images_extracted'] for r in extraction_results)
avg_time = np.mean([r['extraction_time'] for r in extraction_results if r['extraction_time'] > 0])

print("=" * 70)
print(f"✓ Extraction Summary:")
print(f"  - Successful: {successful}/{len(extraction_results)}")
print(f"  - Total images extracted: {total_extracted}")
print(f"  - Average extraction time: {avg_time:.2f}s")
# Out:
# Extracting images using new PyMuPDF 1.26.6 version (normal mode)...
# ======================================================================
# Processing PDFs:   0%|          | 0/285 [00:00<?, ?it/s]
#   ✓ PDF-00001: 6 images, 0.84s
#   ✓ PDF-00002: 5 images, 0.52s
#   ✓ PDF-00003: 5 images, 0.66s
#   ✓ PDF-00004: 11 images, 0.55s
#   ✓ PDF-00005: 10 images, 0.18s
#   ✓ PDF-00006: 10 images, 0.24s
#   ✓ PDF-00007: 7 images, 0.26s
#   ✓ PDF-00008: 2 images, 0.25s
#   ✓ PDF-00009: 8 images, 0.26s
#   ✓ PDF-00010: 5 images, 1.45s
#   ✓ PDF-00011: 11 images, 0.39s
#   ✓ PDF-00012: 12 images, 0.23s
#   ✓ PDF-00013: 10 images, 0.26s
#   ✓ PDF-00014: 66 images, 0.20s
#   ✓ PDF-00015: 7 images, 0.18s
#   ✓ PDF-00016: 70 images, 0.35s
#   ✓ PDF-00017: 10 images, 1.56s
#   ✓ PDF-00018: 11 images, 0.34s
#   ✓ PDF-00019: 10 images, 0.45s
#   ✓ PDF-00020: 25 images, 0.26s
#   ✓ PDF-00021: 13 images, 0.50s
#   ✓ PDF-00022: 11 images, 1.21s
#   ✓ PDF-00023: 9 images, 1.42s
#   ✓ PDF-00024: 7 images, 1.10s
#   ✓ PDF-00025: 2 images, 0.45s
#   ✓ PDF-00026: 4 images, 0.06s
#   ✓ PDF-00027: 3 images, 0.19s
#   ✓ PDF-00028: 4 images, 0.18s
#   ✓ PDF-00029: 8 images, 0.42s
#   ✓ PDF-00030: 9 images, 0.34s
#   ✓ PDF-00031: 10 images, 0.66s
#   ✓ PDF-00032: 5 images, 0.23s
#   ✓ PDF-00033: 8 images, 0.30s
#   ✓ PDF-00034: 7 images, 0.23s
#   ✓ PDF-00035: 4 images, 0.66s
#   ✓ PDF-00036: 4 images, 0.14s
#   ✓ PDF-00037: 7 images, 1.00s
#   ✓ PDF-00038: 4 images, 0.34s
#   ✓ PDF-00039: 36 images, 0.26s
#   ✓ PDF-00040: 12 images, 0.20s
#   ✓ PDF-00041: 11 images, 0.23s
#   ✓ PDF-00042: 7 images, 0.18s
#   ✓ PDF-00043: 5 images, 0.16s
#   ✓ PDF-00044: 6 images, 0.37s
#   ✓ PDF-00045: 1 images, 0.04s
#   ✓ PDF-00046: 10 images, 0.27s
#   ✓ PDF-00047: 17 images, 0.80s
#   ✓ PDF-00048: 14 images, 0.14s
#   ✓ PDF-00049: 5 images, 0.23s
#   ✓ PDF-00050: 8 images, 0.93s
#   ✓ PDF-00051: 5 images, 0.12s
#   ✓ PDF-00052: 8 images, 0.66s
#   ✓ PDF-00053: 44 images, 0.15s
#   ✓ PDF-00054: 62 images, 0.25s
#   ✓ PDF-00055: 8 images, 0.15s
#   ✓ PDF-00056: 8 images, 0.65s
#   ✓ PDF-00057: 8 images, 0.91s
#   ✓ PDF-00058: 8 images, 0.26s
#   ✓ PDF-00059: 8 images, 0.18s
#   ✓ PDF-00060: 8 images, 0.16s
#   ✓ PDF-00061: 24 images, 0.20s
#   ✓ PDF-00062: 8 images, 0.16s
#   ✓ PDF-00063: 8 images, 0.15s
#   ✓ PDF-00064: 10 images, 0.81s
#   ✓ PDF-00065: 42 images, 0.16s
#   ✓ PDF-00066: 21 images, 0.15s
#   ✓ PDF-00067: 9 images, 0.21s
#   ✓ PDF-00068: 8 images, 0.15s
#   ✓ PDF-00069: 18 images, 2.28s
#   ✓ PDF-00070: 8 images, 0.84s
#   ✓ PDF-00071: 8 images, 0.73s
#   ✓ PDF-00072: 37 images, 0.82s
#   ✓ PDF-00073: 9 images, 0.44s
#   ✓ PDF-00074: 15 images, 1.32s
#   ✓ PDF-00075: 7 images, 0.64s
#   ✓ PDF-00076: 11 images, 0.94s
#   ✓ PDF-00077: 6 images, 0.49s
#   ✓ PDF-00078: 68 images, 0.35s
#   ✓ PDF-00079: 8 images, 0.43s
#   ✓ PDF-00080: 10 images, 0.23s
#   ✓ PDF-00081: 8 images, 0.18s
#   ✓ PDF-00082: 8 images, 0.35s
#   ✓ PDF-00083: 8 images, 0.46s
#   ✓ PDF-00084: 7 images, 0.92s
#   ✓ PDF-00085: 7 images, 0.59s
#   ✓ PDF-00086: 10 images, 0.46s
#   ✓ PDF-00087: 65 images, 0.74s
#   ✓ PDF-00088: 7 images, 0.28s
#   ✓ PDF-00089: 9 images, 3.39s
#   ✓ PDF-00090: 6 images, 2.31s
#   ✓ PDF-00091: 6 images, 0.82s
#   ✓ PDF-00092: 8 images, 1.85s
#   ✓ PDF-00093: 30 images, 0.50s
#   ✓ PDF-00094: 7 images, 0.36s
#   ✓ PDF-00095: 21 images, 0.57s
#   ✓ PDF-00096: 7 images, 0.21s
#   ✓ PDF-00097: 5 images, 0.65s
#   ✓ PDF-00098: 8 images, 0.44s
#   ✓ PDF-00099: 10 images, 2.32s
#   ✓ PDF-00100: 6 images, 0.22s
#   ✓ PDF-00101: 6 images, 0.84s
#   ✓ PDF-00102: 12 images, 1.11s
#   ✓ PDF-00103: 12 images, 3.87s
#   ✓ PDF-00104: 9 images, 1.14s
#   ✓ PDF-00105: 6 images, 4.44s
#   ✓ PDF-00106: 9 images, 1.98s
#   ✓ PDF-00107: 9 images, 1.93s
#   ✓ PDF-00108: 8 images, 1.10s
#   ✓ PDF-00109: 5 images, 0.22s
#   ✓ PDF-00110: 5 images, 0.18s
#   ✓ PDF-00111: 7 images, 2.23s
#   ✓ PDF-00112: 7 images, 3.15s
#   ✓ PDF-00113: 7 images, 1.51s
#   ✓ PDF-00114: 9 images, 1.32s
#   ✓ PDF-00115: 5 images, 10.72s
#   ✓ PDF-00116: 21 images, 0.93s
#   ✓ PDF-00117: 7 images, 0.98s
#   ✓ PDF-00118: 6 images, 1.36s
#   ✓ PDF-00119: 7 images, 1.30s
#   ✓ PDF-00120: 7 images, 0.57s
#   ✓ PDF-00121: 4 images, 0.48s
#   ✓ PDF-00122: 7 images, 0.35s
#   ✓ PDF-00123: 13 images, 8.01s
#   ✓ PDF-00124: 9 images, 2.81s
#   ✓ PDF-00125: 10 images, 2.98s
#   ✓ PDF-00126: 92 images, 1.80s
#   ✓ PDF-00127: 11 images, 1.21s
#   ✓ PDF-00128: 12 images, 6.21s
#   ✓ PDF-00129: 4 images, 0.68s
#   ✓ PDF-00130: 9 images, 2.50s
#   ✓ PDF-00131: 5 images, 0.95s
#   ✓ PDF-00132: 8 images, 0.26s
#   ✓ PDF-00133: 7 images, 1.64s
#   ✓ PDF-00134: 12 images, 1.05s
#   ✓ PDF-00135: 8 images, 4.38s
#   ✓ PDF-00136: 4 images, 2.88s
#   ✓ PDF-00137: 11 images, 0.55s
#   ✓ PDF-00138: 9 images, 0.55s
#   ✓ PDF-00139: 13 images, 1.00s
#   ✓ PDF-00140: 10 images, 0.90s
#   ✓ PDF-00141: 6 images, 0.39s
#   ✓ PDF-00142: 12 images, 0.91s
#   ✓ PDF-00143: 12 images, 0.52s
#   ✓ PDF-00144: 12 images, 1.26s
#   ✓ PDF-00145: 228 images, 5.80s
#   ✓ PDF-00146: 12 images, 2.51s
#   ✓ PDF-00147: 7 images, 0.19s
#   ✓ PDF-00148: 3 images, 1.16s
#   ✓ PDF-00149: 8 images, 0.28s
#   ✓ PDF-00150: 7 images, 1.48s
#   ✓ PDF-00151: 6 images, 0.23s
#   ✓ PDF-00152: 2 images, 1.98s
#   ✓ PDF-00153: 6 images, 0.62s
#   ✓ PDF-00154: 9 images, 1.35s
#   ✓ PDF-00155: 10 images, 3.84s
#   ✓ PDF-00156: 8 images, 0.32s
#   ✓ PDF-00157: 7 images, 2.77s
#   ✓ PDF-00158: 25 images, 1.34s
# ERROR: xfigs/PDF-00159/p-7- IMAGE IS CORRUPT. TRYING WITH 1.5 DISTANCE
# ERROR: xfigs/PDF-00159/p-7- IMAGE IS CORRUPT. TRYING WITH 1.5 DISTANCE
#   ✓ PDF-00159: 70 images, 1.00s
#   ✓ PDF-00160: 7 images, 0.23s
#   ✓ PDF-00161: 4 images, 0.14s
#   ✓ PDF-00162: 7 images, 0.21s
#   ✓ PDF-00163: 7 images, 1.71s
#   ✓ PDF-00164: 6 images, 0.19s
#   ✓ PDF-00165: 3 images, 0.47s
#   ✓ PDF-00166: 4 images, 0.43s
#   ✓ PDF-00167: 9 images, 0.17s
#   ✓ PDF-00168: 4 images, 0.19s
#   ✓ PDF-00169: 23 images, 0.54s
#   ✓ PDF-00170: 8 images, 0.33s
#   ✓ PDF-00171: 8 images, 0.48s
#   ✓ PDF-00172: 9 images, 0.31s
#   ✓ PDF-00173: 7 images, 0.45s
#   ✓ PDF-00174: 8 images, 0.92s
#   ✓ PDF-00175: 7 images, 0.50s
#   ✓ PDF-00176: 7 images, 0.51s
#   ✓ PDF-00177: 6 images, 3.02s
#   ✓ PDF-00178: 6 images, 0.12s
#   ✓ PDF-00179: 4 images, 0.12s
#   ✓ PDF-00180: 5 images, 0.69s
#   ✓ PDF-00181: 2 images, 0.50s
#   ✓ PDF-00182: 6 images, 0.24s
#   ✓ PDF-00183: 6 images, 0.19s
#   ✓ PDF-00184: 5 images, 0.11s
#   ✓ PDF-00185: 6 images, 0.43s
#   ✓ PDF-00186: 3 images, 0.10s
#   ✓ PDF-00187: 8 images, 4.37s
#   ✓ PDF-00188: 6 images, 0.48s
#   ✓ PDF-00189: 6 images, 0.97s
#   ✓ PDF-00190: 4 images, 2.07s
#   ✓ PDF-00191: 12 images, 0.39s
#   ✓ PDF-00192: 9 images, 0.22s
#   ✓ PDF-00193: 7 images, 0.53s
#   ✓ PDF-00194: 10 images, 0.54s
#   ✓ PDF-00195: 107 images, 2.98s
#   ✓ PDF-00196: 1 images, 0.07s
#   ✓ PDF-00197: 11 images, 1.85s
#   ✓ PDF-00198: 4 images, 0.27s
#   ✓ PDF-00199: 7 images, 1.48s
#   ✓ PDF-00200: 21 images, 0.34s
#   ✓ PDF-00201: 8 images, 1.20s
#   ✓ PDF-00202: 14 images, 2.59s
#   ✓ PDF-00203: 21 images, 0.60s
#   ✓ PDF-00204: 39 images, 0.55s
#   ✓ PDF-00205: 39 images, 0.41s
#   ✓ PDF-00206: 207 images, 5.39s
#   ✓ PDF-00207: 4 images, 0.28s
#   ✓ PDF-00208: 5 images, 0.26s
#   ✓ PDF-00209: 68 images, 0.36s
#   ✓ PDF-00210: 15 images, 0.44s
#   ✓ PDF-00211: 7 images, 0.14s
# ERROR: xfigs/PDF-00212/p-4- IMAGE IS CORRUPT. TRYING WITH 1.5 DISTANCE
# ERROR: xfigs/PDF-00212/p-4- IMAGE IS CORRUPT. TRYING WITH 2.0 DISTANCE
#   ✓ PDF-00212: 158 images, 1.94s
#   ✓ PDF-00213: 12 images, 0.69s
#   ✓ PDF-00214: 14 images, 1.59s
#   ✓ PDF-00215: 2 images, 0.20s
#   ✓ PDF-00216: 5 images, 1.06s
#   ✓ PDF-00217: 7 images, 1.19s
#   ✓ PDF-00218: 1 images, 0.76s
#   ✓ PDF-00219: 10 images, 5.77s
#   ✓ PDF-00220: 12 images, 2.60s
#   ✓ PDF-00221: 10 images, 11.74s
#   ✓ PDF-00222: 6 images, 0.23s
#   ✓ PDF-00223: 13 images, 0.21s
#   ✓ PDF-00224: 24 images, 0.76s
#   ✓ PDF-00225: 13 images, 12.07s
#   ✓ PDF-00226: 7 images, 1.01s
#   ✓ PDF-00227: 5 images, 0.39s
#   ✓ PDF-00228: 6 images, 1.70s
#   ✓ PDF-00229: 7 images, 0.67s
#   ✓ PDF-00230: 4 images, 1.57s
#   ✓ PDF-00231: 6 images, 1.44s
#   ✓ PDF-00232: 3 images, 2.55s
#   ✓ PDF-00233: 7 images, 6.26s
#   ✓ PDF-00234: 18 images, 0.62s
#   ✓ PDF-00235: 7 images, 0.29s
#   ✓ PDF-00236: 6 images, 3.73s
#   ✓ PDF-00237: 8 images, 2.07s
#   ✓ PDF-00238: 10 images, 1.81s
#   ✓ PDF-00239: 11 images, 2.47s
#   ✓ PDF-00240: 12 images, 1.06s
#   ✓ PDF-00241: 20 images, 0.88s
#   ✓ PDF-00242: 8 images, 1.99s
#   ✓ PDF-00243: 8 images, 1.69s
#   ✓ PDF-00244: 11 images, 0.99s
#   ✓ PDF-00245: 6 images, 4.57s
#   ✓ PDF-00246: 6 images, 0.93s
#   ✓ PDF-00247: 4 images, 0.41s
#   ✓ PDF-00248: 4 images, 0.65s
#   ✓ PDF-00249: 8 images, 0.31s
#   ✓ PDF-00250: 5 images, 0.34s
#   ✓ PDF-00251: 96 images, 1.63s
#   ✓ PDF-00252: 59 images, 2.32s
#   ✓ PDF-00253: 7 images, 2.43s
#   ✓ PDF-00254: 5 images, 0.88s
#   ✓ PDF-00255: 10 images, 0.95s
#   ✓ PDF-00256: 25 images, 1.66s
#   ✓ PDF-00257: 8 images, 4.39s
#   ✓ PDF-00258: 5 images, 0.67s
#   ✓ PDF-00259: 9 images, 1.67s
#   ✓ PDF-00260: 10 images, 1.19s
#   ✓ PDF-00261: 9 images, 1.35s
#   ✓ PDF-00262: 8 images, 4.63s
#   ✓ PDF-00263: 7 images, 1.22s
#   ✓ PDF-00264: 10 images, 0.92s
#   ✓ PDF-00265: 9 images, 2.00s
#   ✓ PDF-00266: 49 images, 1.26s
#   ✓ PDF-00267: 5 images, 0.66s
#   ✓ PDF-00268: 5 images, 5.37s
#   ✓ PDF-00269: 8 images, 0.48s
#   ✓ PDF-00270: 9 images, 4.14s
#   ✓ PDF-00271: 9 images, 4.41s
#   ✓ PDF-00272: 13 images, 2.43s
#   ✓ PDF-00273: 4 images, 0.24s
#   ✓ PDF-00274: 11 images, 2.53s
#   ✓ PDF-00275: 4 images, 1.35s
#   ✓ PDF-00276: 8 images, 4.21s
#   ✓ PDF-00277: 11 images, 1.37s
#   ✓ PDF-00278: 11 images, 2.12s
#   ✓ PDF-00279: 8 images, 6.66s
#   ✓ PDF-00280: 7 images, 0.21s
#   ✓ PDF-00281: 9 images, 3.64s
#   ✓ PDF-00282: 7 images, 2.48s
#   ✓ PDF-00283: 27 images, 1.65s
#   ✓ PDF-00284: 8 images, 2.59s
#   ✓ PDF-00285: 6 images, 2.81s
# ======================================================================
# ✓ Extraction Summary:
#   - Successful: 285/285
#   - Total images extracted: 3966
#   - Average extraction time: 1.29s
